# %% [markdown]
# Same Data loading Code from linear&fnn code from Checkpoint.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import torch.nn as nn
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# %%
# Clean data path
clean_path = "/content/drive/MyDrive/Colab Notebooks/retail_forecasting_sequences"

X_train_clean = np.load(f"{clean_path}/X_train_reshaped.npy")
y_train_clean = np.load(f"{clean_path}/y_train_reshaped.npy")
X_val_clean   = np.load(f"{clean_path}/X_val_reshaped.npy")
y_val_clean   = np.load(f"{clean_path}/y_val_reshaped.npy")
X_test_clean  = np.load(f"{clean_path}/X_test_reshaped.npy")
y_test_clean  = np.load(f"{clean_path}/y_test_reshaped.npy")

print("CLEAN DATA")
print("Train:", X_train_clean.shape, y_train_clean.shape)
print("Val:  ", X_val_clean.shape, y_val_clean.shape)
print("Test: ", X_test_clean.shape, y_test_clean.shape)

# Noisy data path
noisy_path = f"{clean_path}/retail_forecasting_sequences_noisy"

X_train_noisy = np.load(f"{noisy_path}/X_train_noisy_reshaped.npy")
y_train_noisy = np.load(f"{noisy_path}/y_train_noisy_reshaped.npy")
X_val_noisy   = np.load(f"{noisy_path}/X_val_noisy_reshaped.npy")
y_val_noisy   = np.load(f"{noisy_path}/y_val_noisy_reshaped.npy")
X_test_noisy  = np.load(f"{noisy_path}/X_test_noisy_reshaped.npy")
y_test_noisy  = np.load(f"{noisy_path}/y_test_noisy_reshaped.npy")

print("\n NOISY DATA")
print("Train:", X_train_noisy.shape, y_train_noisy.shape)
print("Val:  ", X_val_noisy.shape, y_val_noisy.shape)
print("Test: ", X_test_noisy.shape, y_test_noisy.shape)
# Out:
# CLEAN DATA
# Train: (202883, 12, 19) (202883, 6, 19)
# Val:   (43475, 12, 19) (43475, 6, 19)
# Test:  (43475, 12, 19) (43475, 6, 19)
#
#  NOISY DATA
# Train: (202883, 12, 19) (202883, 6, 19)
# Val:   (43474, 12, 19) (43474, 6, 19)
# Test:  (43476, 12, 19) (43476, 6, 19)

# %%
train_loader_clean = get_loaders(X_train_clean, y_train_clean)
val_loader_clean   = get_loaders(X_val_clean, y_val_clean)
test_loader_clean  = get_loaders(X_test_clean, y_test_clean)

train_loader_noisy = get_loaders(X_train_noisy, y_train_noisy)
val_loader_noisy   = get_loaders(X_val_noisy, y_val_noisy)
test_loader_noisy  = get_loaders(X_test_noisy, y_test_noisy)

# %% [markdown]
# The Basice Structure is from our Checkpoint

# %%
import torch
import torch.nn as nn

class LSTM_Autoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers, dropout, output_seq_len):
        super(LSTM_Autoencoder, self).__init__()
        self.output_seq_len = output_seq_len

        self.encoder = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0
        )

        self.decoder = nn.LSTM(
            input_size=hidden_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0
        )

        self.output_layer = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # Encoder: input shape (batch_size, seq_len, input_dim)
        _, (hidden, cell) = self.encoder(x)

        # Decoder input: repeat last hidden state across output_seq_len steps
        decoder_input = hidden[-1].unsqueeze(1).repeat(1, self.output_seq_len, 1)

        # Decoder: use repeated hidden state and original encoder hidden/cell
        decoded_output, _ = self.decoder(decoder_input, (hidden, cell))

        # Project to output dimension at each timestep
        output = self.output_layer(decoded_output)
        return output

# %% [markdown]
# Hyperparameter settings

# %%
input_dim = X_train_clean.shape[2]
output_dim = y_train_clean.shape[2]
output_seq_len = y_train_clean.shape[1]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameter sets: (hidden_dim, num_layers, dropout, learning_rate)
hyperparams_list = [
    (64, 1, 0.1, 0.001),
    (128, 1, 0.2, 0.001),
    (128, 2, 0.3, 0.0005),
    (256, 2, 0.3, 0.0003),
    (64, 3, 0.5, 0.0001),
]

results_lstm = []

for data_mode in ['clean', 'noisy']:
    # Select dataset
    if data_mode == 'clean':
        train_loader, val_loader, test_loader = train_loader_clean, val_loader_clean, test_loader_clean
        y_test = y_test_clean
    else:
        train_loader, val_loader, test_loader = train_loader_noisy, val_loader_noisy, test_loader_noisy
        y_test = y_test_noisy

    for i, (hidden_dim, num_layers, dropout, lr) in enumerate(hyperparams_list, 1):
        print(f"Training [{data_mode.upper()}] LSTM Set {i} — hidden={hidden_dim}, layers={num_layers}, dropout={dropout}, lr={lr}")

        model = LSTM_Autoencoder(
            input_dim=input_dim,
            hidden_dim=hidden_dim,
            output_dim=output_dim,
            num_layers=num_layers,
            dropout=dropout,
            output_seq_len=output_seq_len
        ).to(device)

        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)

        trained_model, train_losses, val_losses = train_lstm_model(
            model, train_loader, val_loader, epochs=20,
            criterion=criterion, optimizer=optimizer
        )

        # Test prediction
        model.eval()
        preds, targets = [], []
        with torch.no_grad():
            for x_batch, y_batch in test_loader:
                x_batch = x_batch.float().to(device)
                y_batch = y_batch.float().to(device)
                output = model(x_batch)
                preds.append(output.cpu().numpy())
                targets.append(y_batch.cpu().numpy())

        preds = np.concatenate(preds, axis=0).reshape(-1, output_dim)
        targets = np.concatenate(targets, axis=0).reshape(-1, output_dim)

        # Metrics
        mse = mean_squared_error(targets, preds)
        mae = mean_absolute_error(targets, preds)
        rmse = np.sqrt(mse)
        r2 = r2_score(targets, preds)

        # Save results
        results_lstm.append({
            "data_mode": data_mode,
            "set": i,
            "hidden_dim": hidden_dim,
            "num_layers": num_layers,
            "dropout": dropout,
            "lr": lr,
            "train_losses": train_losses,
            "val_losses": val_losses,
            "test_mse": mse,
            "test_mae": mae,
            "test_rmse": rmse,
            "test_r2": r2,
            "model": trained_model
        })


lstm_model = LSTM_Autoencoder(
    input_dim, hidden_dim, output_dim,
    num_layers, dropout, output_seq_len
).to(device)
# Out:
# Training [CLEAN] LSTM Set 1 — hidden=64, layers=1, dropout=0.1, lr=0.001
# Epoch 1/20 | Train Loss: 0.0326 | Val Loss: 0.0561
# Epoch 2/20 | Train Loss: 0.0267 | Val Loss: 0.0503
# Epoch 3/20 | Train Loss: 0.0253 | Val Loss: 0.0476
# Epoch 4/20 | Train Loss: 0.0244 | Val Loss: 0.0461
# Epoch 5/20 | Train Loss: 0.0237 | Val Loss: 0.0452
# Epoch 6/20 | Train Loss: 0.0232 | Val Loss: 0.0440
# Epoch 7/20 | Train Loss: 0.0229 | Val Loss: 0.0430
# Epoch 8/20 | Train Loss: 0.0227 | Val Loss: 0.0419
# Epoch 9/20 | Train Loss: 0.0225 | Val Loss: 0.0403
# Epoch 10/20 | Train Loss: 0.0222 | Val Loss: 0.0380
# Epoch 11/20 | Train Loss: 0.0221 | Val Loss: 0.0362
# Epoch 12/20 | Train Loss: 0.0219 | Val Loss: 0.0350
# Epoch 13/20 | Train Loss: 0.0218 | Val Loss: 0.0344
# Epoch 14/20 | Train Loss: 0.0217 | Val Loss: 0.0340
# Epoch 15/20 | Train Loss: 0.0216 | Val Loss: 0.0336
# Epoch 16/20 | Train Loss: 0.0216 | Val Loss: 0.0333
# Epoch 17/20 | Train Loss: 0.0215 | Val Loss: 0.0330
# Epoch 18/20 | Train Loss: 0.0215 | Val Loss: 0.0329
# Epoch 19/20 | Train Loss: 0.0214 | Val Loss: 0.0324
# Epoch 20/20 | Train Loss: 0.0214 | Val Loss: 0.0334
# Training [CLEAN] LSTM Set 2 — hidden=128, layers=1, dropout=0.2, lr=0.001
# Epoch 1/20 | Train Loss: 0.0314 | Val Loss: 0.0516
# Epoch 2/20 | Train Loss: 0.0256 | Val Loss: 0.0484
# Epoch 3/20 | Train Loss: 0.0242 | Val Loss: 0.0474
# Epoch 4/20 | Train Loss: 0.0233 | Val Loss: 0.0465
# Epoch 5/20 | Train Loss: 0.0227 | Val Loss: 0.0450
# Epoch 6/20 | Train Loss: 0.0224 | Val Loss: 0.0437
# Epoch 7/20 | Train Loss: 0.0221 | Val Loss: 0.0424
# Epoch 8/20 | Train Loss: 0.0219 | Val Loss: 0.0404
# Epoch 9/20 | Train Loss: 0.0217 | Val Loss: 0.0398
# Epoch 10/20 | Train Loss: 0.0216 | Val Loss: 0.0386
# Epoch 11/20 | Train Loss: 0.0215 | Val Loss: 0.0381
# Epoch 12/20 | Train Loss: 0.0214 | Val Loss: 0.0375
# Epoch 13/20 | Train Loss: 0.0213 | Val Loss: 0.0356
# Epoch 14/20 | Train Loss: 0.0211 | Val Loss: 0.0346
# Epoch 15/20 | Train Loss: 0.0211 | Val Loss: 0.0355
# Epoch 16/20 | Train Loss: 0.0210 | Val Loss: 0.0353
# Epoch 17/20 | Train Loss: 0.0210 | Val Loss: 0.0348
# Epoch 18/20 | Train Loss: 0.0209 | Val Loss: 0.0335
# Epoch 19/20 | Train Loss: 0.0208 | Val Loss: 0.0328
# Epoch 20/20 | Train Loss: 0.0208 | Val Loss: 0.0319
# Training [CLEAN] LSTM Set 3 — hidden=128, layers=2, dropout=0.3, lr=0.0005
# Epoch 1/20 | Train Loss: 0.0361 | Val Loss: 0.0587
# Epoch 2/20 | Train Loss: 0.0277 | Val Loss: 0.0538
# Epoch 3/20 | Train Loss: 0.0259 | Val Loss: 0.0516
# Epoch 4/20 | Train Loss: 0.0248 | Val Loss: 0.0500
# Epoch 5/20 | Train Loss: 0.0240 | Val Loss: 0.0483
# Epoch 6/20 | Train Loss: 0.0234 | Val Loss: 0.0472
# Epoch 7/20 | Train Loss: 0.0230 | Val Loss: 0.0459
# Epoch 8/20 | Train Loss: 0.0226 | Val Loss: 0.0448
# Epoch 9/20 | Train Loss: 0.0224 | Val Loss: 0.0437
# Epoch 10/20 | Train Loss: 0.0222 | Val Loss: 0.0426
# Epoch 11/20 | Train Loss: 0.0220 | Val Loss: 0.0418
# Epoch 12/20 | Train Loss: 0.0219 | Val Loss: 0.0419
# Epoch 13/20 | Train Loss: 0.0218 | Val Loss: 0.0409
# Epoch 14/20 | Train Loss: 0.0216 | Val Loss: 0.0388
# Epoch 15/20 | Train Loss: 0.0215 | Val Loss: 0.0391
# Epoch 16/20 | Train Loss: 0.0214 | Val Loss: 0.0381
# Epoch 17/20 | Train Loss: 0.0213 | Val Loss: 0.0369
# Epoch 18/20 | Train Loss: 0.0213 | Val Loss: 0.0363
# Epoch 19/20 | Train Loss: 0.0211 | Val Loss: 0.0349
# Epoch 20/20 | Train Loss: 0.0211 | Val Loss: 0.0353
# Training [CLEAN] LSTM Set 4 — hidden=256, layers=2, dropout=0.3, lr=0.0003
# Epoch 1/20 | Train Loss: 0.0365 | Val Loss: 0.0608
# Epoch 2/20 | Train Loss: 0.0277 | Val Loss: 0.0531
# Epoch 3/20 | Train Loss: 0.0260 | Val Loss: 0.0509
# Epoch 4/20 | Train Loss: 0.0248 | Val Loss: 0.0491
# Epoch 5/20 | Train Loss: 0.0239 | Val Loss: 0.0476
# Epoch 6/20 | Train Loss: 0.0232 | Val Loss: 0.0459
# Epoch 7/20 | Train Loss: 0.0228 | Val Loss: 0.0445
# Epoch 8/20 | Train Loss: 0.0224 | Val Loss: 0.0440
# Epoch 9/20 | Train Loss: 0.0222 | Val Loss: 0.0433
# Epoch 10/20 | Train Loss: 0.0220 | Val Loss: 0.0426
# Epoch 11/20 | Train Loss: 0.0218 | Val Loss: 0.0430
# Epoch 12/20 | Train Loss: 0.0217 | Val Loss: 0.0425
# Epoch 13/20 | Train Loss: 0.0216 | Val Loss: 0.0416
# Epoch 14/20 | Train Loss: 0.0215 | Val Loss: 0.0399
# Epoch 15/20 | Train Loss: 0.0213 | Val Loss: 0.0375
# Epoch 16/20 | Train Loss: 0.0212 | Val Loss: 0.0377
# Epoch 17/20 | Train Loss: 0.0210 | Val Loss: 0.0378
# Epoch 18/20 | Train Loss: 0.0209 | Val Loss: 0.0366
# Epoch 19/20 | Train Loss: 0.0208 | Val Loss: 0.0352
# Epoch 20/20 | Train Loss: 0.0207 | Val Loss: 0.0352
# Training [CLEAN] LSTM Set 5 — hidden=64, layers=3, dropout=0.5, lr=0.0001
# Epoch 1/20 | Train Loss: 0.0523 | Val Loss: 0.0656
# Epoch 2/20 | Train Loss: 0.0392 | Val Loss: 0.0598
# Epoch 3/20 | Train Loss: 0.0359 | Val Loss: 0.0560
# Epoch 4/20 | Train Loss: 0.0336 | Val Loss: 0.0550
# Epoch 5/20 | Train Loss: 0.0323 | Val Loss: 0.0541
# Epoch 6/20 | Train Loss: 0.0312 | Val Loss: 0.0538
# Epoch 7/20 | Train Loss: 0.0303 | Val Loss: 0.0530
# Epoch 8/20 | Train Loss: 0.0296 | Val Loss: 0.0519
# Epoch 9/20 | Train Loss: 0.0290 | Val Loss: 0.0514
# Epoch 10/20 | Train Loss: 0.0287 | Val Loss: 0.0507
# Epoch 11/20 | Train Loss: 0.0284 | Val Loss: 0.0500
# Epoch 12/20 | Train Loss: 0.0281 | Val Loss: 0.0499
# Epoch 13/20 | Train Loss: 0.0279 | Val Loss: 0.0492
# Epoch 14/20 | Train Loss: 0.0277 | Val Loss: 0.0490
# Epoch 15/20 | Train Loss: 0.0275 | Val Loss: 0.0485
# Epoch 16/20 | Train Loss: 0.0273 | Val Loss: 0.0482
# Epoch 17/20 | Train Loss: 0.0272 | Val Loss: 0.0475
# Epoch 18/20 | Train Loss: 0.0270 | Val Loss: 0.0469
# Epoch 19/20 | Train Loss: 0.0268 | Val Loss: 0.0463
# Epoch 20/20 | Train Loss: 0.0266 | Val Loss: 0.0458
# Training [NOISY] LSTM Set 1 — hidden=64, layers=1, dropout=0.1, lr=0.001
# Epoch 1/20 | Train Loss: 0.0273 | Val Loss: 0.0424
# Epoch 2/20 | Train Loss: 0.0215 | Val Loss: 0.0416
# Epoch 3/20 | Train Loss: 0.0208 | Val Loss: 0.0403
# Epoch 4/20 | Train Loss: 0.0204 | Val Loss: 0.0395
# Epoch 5/20 | Train Loss: 0.0202 | Val Loss: 0.0391
# Epoch 6/20 | Train Loss: 0.0201 | Val Loss: 0.0383
# Epoch 7/20 | Train Loss: 0.0199 | Val Loss: 0.0383
# Epoch 8/20 | Train Loss: 0.0198 | Val Loss: 0.0375
# Epoch 9/20 | Train Loss: 0.0198 | Val Loss: 0.0368
# Epoch 10/20 | Train Loss: 0.0197 | Val Loss: 0.0362
# Epoch 11/20 | Train Loss: 0.0196 | Val Loss: 0.0350
# Epoch 12/20 | Train Loss: 0.0195 | Val Loss: 0.0334
# Epoch 13/20 | Train Loss: 0.0194 | Val Loss: 0.0317
# Epoch 14/20 | Train Loss: 0.0193 | Val Loss: 0.0300
# Epoch 15/20 | Train Loss: 0.0192 | Val Loss: 0.0288
# Epoch 16/20 | Train Loss: 0.0191 | Val Loss: 0.0277
# Epoch 17/20 | Train Loss: 0.0191 | Val Loss: 0.0268
# Epoch 18/20 | Train Loss: 0.0190 | Val Loss: 0.0261
# Epoch 19/20 | Train Loss: 0.0190 | Val Loss: 0.0256
# Epoch 20/20 | Train Loss: 0.0189 | Val Loss: 0.0251
# Training [NOISY] LSTM Set 2 — hidden=128, layers=1, dropout=0.2, lr=0.001
# Epoch 1/20 | Train Loss: 0.0258 | Val Loss: 0.0428
# Epoch 2/20 | Train Loss: 0.0211 | Val Loss: 0.0400
# Epoch 3/20 | Train Loss: 0.0204 | Val Loss: 0.0400
# Epoch 4/20 | Train Loss: 0.0201 | Val Loss: 0.0397
# Epoch 5/20 | Train Loss: 0.0199 | Val Loss: 0.0395
# Epoch 6/20 | Train Loss: 0.0198 | Val Loss: 0.0394
# Epoch 7/20 | Train Loss: 0.0196 | Val Loss: 0.0385
# Epoch 8/20 | Train Loss: 0.0195 | Val Loss: 0.0379
# Epoch 9/20 | Train Loss: 0.0194 | Val Loss: 0.0372
# Epoch 10/20 | Train Loss: 0.0193 | Val Loss: 0.0379
# Epoch 11/20 | Train Loss: 0.0193 | Val Loss: 0.0368
# Epoch 12/20 | Train Loss: 0.0192 | Val Loss: 0.0358
# Epoch 13/20 | Train Loss: 0.0191 | Val Loss: 0.0341
# Epoch 14/20 | Train Loss: 0.0191 | Val Loss: 0.0325
# Epoch 15/20 | Train Loss: 0.0190 | Val Loss: 0.0311
# Epoch 16/20 | Train Loss: 0.0190 | Val Loss: 0.0292
# Epoch 17/20 | Train Loss: 0.0189 | Val Loss: 0.0276
# Epoch 18/20 | Train Loss: 0.0188 | Val Loss: 0.0264
# Epoch 19/20 | Train Loss: 0.0188 | Val Loss: 0.0251
# Epoch 20/20 | Train Loss: 0.0187 | Val Loss: 0.0244
# Training [NOISY] LSTM Set 3 — hidden=128, layers=2, dropout=0.3, lr=0.0005
# Epoch 1/20 | Train Loss: 0.0293 | Val Loss: 0.0441
# Epoch 2/20 | Train Loss: 0.0218 | Val Loss: 0.0413
# Epoch 3/20 | Train Loss: 0.0209 | Val Loss: 0.0404
# Epoch 4/20 | Train Loss: 0.0205 | Val Loss: 0.0399
# Epoch 5/20 | Train Loss: 0.0202 | Val Loss: 0.0396
# Epoch 6/20 | Train Loss: 0.0200 | Val Loss: 0.0389
# Epoch 7/20 | Train Loss: 0.0199 | Val Loss: 0.0387
# Epoch 8/20 | Train Loss: 0.0197 | Val Loss: 0.0378
# Epoch 9/20 | Train Loss: 0.0196 | Val Loss: 0.0375
# Epoch 10/20 | Train Loss: 0.0195 | Val Loss: 0.0372
# Epoch 11/20 | Train Loss: 0.0194 | Val Loss: 0.0369
# Epoch 12/20 | Train Loss: 0.0194 | Val Loss: 0.0365
# Epoch 13/20 | Train Loss: 0.0193 | Val Loss: 0.0356
# Epoch 14/20 | Train Loss: 0.0192 | Val Loss: 0.0343
# Epoch 15/20 | Train Loss: 0.0191 | Val Loss: 0.0338
# Epoch 16/20 | Train Loss: 0.0191 | Val Loss: 0.0334
# Epoch 17/20 | Train Loss: 0.0190 | Val Loss: 0.0328
# Epoch 18/20 | Train Loss: 0.0190 | Val Loss: 0.0320
# Epoch 19/20 | Train Loss: 0.0189 | Val Loss: 0.0319
# Epoch 20/20 | Train Loss: 0.0189 | Val Loss: 0.0317
# Training [NOISY] LSTM Set 4 — hidden=256, layers=2, dropout=0.3, lr=0.0003
# Epoch 1/20 | Train Loss: 0.0295 | Val Loss: 0.0456
# Epoch 2/20 | Train Loss: 0.0221 | Val Loss: 0.0418
# Epoch 3/20 | Train Loss: 0.0210 | Val Loss: 0.0400
# Epoch 4/20 | Train Loss: 0.0205 | Val Loss: 0.0393
# Epoch 5/20 | Train Loss: 0.0202 | Val Loss: 0.0391
# Epoch 6/20 | Train Loss: 0.0200 | Val Loss: 0.0388
# Epoch 7/20 | Train Loss: 0.0198 | Val Loss: 0.0385
# Epoch 8/20 | Train Loss: 0.0197 | Val Loss: 0.0378
# Epoch 9/20 | Train Loss: 0.0196 | Val Loss: 0.0370
# Epoch 10/20 | Train Loss: 0.0194 | Val Loss: 0.0368
# Epoch 11/20 | Train Loss: 0.0194 | Val Loss: 0.0369
# Epoch 12/20 | Train Loss: 0.0193 | Val Loss: 0.0358
# Epoch 13/20 | Train Loss: 0.0192 | Val Loss: 0.0342
# Epoch 14/20 | Train Loss: 0.0191 | Val Loss: 0.0333
# Epoch 15/20 | Train Loss: 0.0190 | Val Loss: 0.0321
# Epoch 16/20 | Train Loss: 0.0190 | Val Loss: 0.0302
# Epoch 17/20 | Train Loss: 0.0189 | Val Loss: 0.0291
# Epoch 18/20 | Train Loss: 0.0188 | Val Loss: 0.0293
# Epoch 19/20 | Train Loss: 0.0188 | Val Loss: 0.0290
# Epoch 20/20 | Train Loss: 0.0187 | Val Loss: 0.0294
# Training [NOISY] LSTM Set 5 — hidden=64, layers=3, dropout=0.5, lr=0.0001
# Epoch 1/20 | Train Loss: 0.0430 | Val Loss: 0.0530
# Epoch 2/20 | Train Loss: 0.0316 | Val Loss: 0.0496
# Epoch 3/20 | Train Loss: 0.0272 | Val Loss: 0.0460
# Epoch 4/20 | Train Loss: 0.0254 | Val Loss: 0.0446
# Epoch 5/20 | Train Loss: 0.0245 | Val Loss: 0.0433
# Epoch 6/20 | Train Loss: 0.0236 | Val Loss: 0.0418
# Epoch 7/20 | Train Loss: 0.0230 | Val Loss: 0.0405
# Epoch 8/20 | Train Loss: 0.0226 | Val Loss: 0.0398
# Epoch 9/20 | Train Loss: 0.0223 | Val Loss: 0.0392
# Epoch 10/20 | Train Loss: 0.0221 | Val Loss: 0.0386
# Epoch 11/20 | Train Loss: 0.0220 | Val Loss: 0.0383
# Epoch 12/20 | Train Loss: 0.0218 | Val Loss: 0.0380
# Epoch 13/20 | Train Loss: 0.0217 | Val Loss: 0.0376
# Epoch 14/20 | Train Loss: 0.0216 | Val Loss: 0.0371
# Epoch 15/20 | Train Loss: 0.0214 | Val Loss: 0.0364
# Epoch 16/20 | Train Loss: 0.0213 | Val Loss: 0.0357
# Epoch 17/20 | Train Loss: 0.0212 | Val Loss: 0.0349
# Epoch 18/20 | Train Loss: 0.0211 | Val Loss: 0.0343
# Epoch 19/20 | Train Loss: 0.0210 | Val Loss: 0.0337
# Epoch 20/20 | Train Loss: 0.0209 | Val Loss: 0.0330

# %%
from tabulate import tabulate

# Collect evaluation summary
summary = []
for res in results_lstm:
    row = [
        res["data_mode"].upper(),
        res["set"],
        res["hidden_dim"],
        res["num_layers"],
        res["dropout"],
        res["lr"],
        round(res["train_losses"][-1], 6),
        round(res["val_losses"][-1], 6),
        round(res["test_mse"], 6),
        round(res["test_mae"], 6),
        round(res["test_rmse"], 6),
        round(res["test_r2"], 6),
    ]
    summary.append(row)

# Table headers
headers = [
    "Data", "Set", "Hidden", "Layers", "Dropout", "LR",
    "Final Train Loss", "Final Val Loss",
    "Test MSE", "Test MAE", "Test RMSE", "Test R²"
]

# Print neatly
print(tabulate(summary, headers=headers, tablefmt="grid"))
# Out:
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | Data   |   Set |   Hidden |   Layers |   Dropout |     LR |   Final Train Loss |   Final Val Loss |   Test MSE |   Test MAE |   Test RMSE |   Test R² |
# +========+=======+==========+==========+===========+========+====================+==================+============+============+=============+===========+
# | CLEAN  |     1 |       64 |        1 |       0.1 | 0.001  |           0.021373 |         0.033359 |   0.031354 |   0.117842 |    0.177071 |  0.561091 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | CLEAN  |     2 |      128 |        1 |       0.2 | 0.001  |           0.020756 |         0.031948 |   0.029914 |   0.111882 |    0.172955 |  0.579171 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | CLEAN  |     3 |      128 |        2 |       0.3 | 0.0005 |           0.02109  |         0.035269 |   0.034908 |   0.117475 |    0.186837 |  0.523887 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | CLEAN  |     4 |      256 |        2 |       0.3 | 0.0003 |           0.020695 |         0.035216 |   0.033575 |   0.115619 |    0.183234 |  0.538032 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | CLEAN  |     5 |       64 |        3 |       0.5 | 0.0001 |           0.026577 |         0.045824 |   0.043156 |   0.140017 |    0.20774  |  0.4113   |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     1 |       64 |        1 |       0.1 | 0.001  |           0.018917 |         0.025109 |   0.022728 |   0.110922 |    0.150757 |  0.203503 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     2 |      128 |        1 |       0.2 | 0.001  |           0.018703 |         0.024432 |   0.022538 |   0.109349 |    0.150127 |  0.208305 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     3 |      128 |        2 |       0.3 | 0.0005 |           0.018865 |         0.031735 |   0.03108  |   0.118607 |    0.176294 |  0.101735 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     4 |      256 |        2 |       0.3 | 0.0003 |           0.018716 |         0.029362 |   0.028938 |   0.116548 |    0.170111 |  0.131673 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     5 |       64 |        3 |       0.5 | 0.0001 |           0.0209   |         0.032956 |   0.031589 |   0.123338 |    0.177734 |  0.092676 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+

# %%
import matplotlib.pyplot as plt
import numpy as np

# Convert to pandas DataFrame for easier plotting
import pandas as pd
df = pd.DataFrame(results_lstm)

# x-axis labels
df["Label"] = df["data_mode"].str.upper() + "_Set" + df["set"].astype(str)

# 1. Final Train & Val Loss
plt.figure(figsize=(12, 5))
x = np.arange(len(df))
bar_width = 0.35
plt.bar(x - bar_width/2, [l[-1] for l in df["train_losses"]], width=bar_width, label='Train Loss')
plt.bar(x + bar_width/2, [l[-1] for l in df["val_losses"]], width=bar_width, label='Val Loss')
plt.xticks(x, df["Label"], rotation=45)
plt.ylabel("Loss")
plt.title("Final Train vs Validation Loss")
plt.legend()
plt.tight_layout()
plt.show()

# 2. Test MSE, MAE, RMSE
plt.figure(figsize=(12, 5))
x = np.arange(len(df))
bar_width = 0.25
plt.bar(x - bar_width, df["test_mse"], width=bar_width, label="MSE")
plt.bar(x, df["test_mae"], width=bar_width, label="MAE")
plt.bar(x + bar_width, df["test_rmse"], width=bar_width, label="RMSE")
plt.xticks(x, df["Label"], rotation=45)
plt.ylabel("Error")
plt.title("Test Error Metrics (MSE, MAE, RMSE)")
plt.legend()
plt.tight_layout()
plt.show()

# 3. R² scores
plt.figure(figsize=(12, 5))
plt.bar(df["Label"], df["test_r2"])
plt.xticks(rotation=45)
plt.ylabel("R² Score")
plt.title("Test R² Scores by Model")
plt.tight_layout()
plt.show()

# 4. R²: Clean vs Noisy
plt.figure(figsize=(10, 5))
for mode in ["CLEAN", "NOISY"]:
    r2_vals = df[df["data_mode"] == mode.lower()]["test_r2"]
    plt.plot(range(1, 6), r2_vals, marker='o', label=mode)
plt.xticks(range(1, 6), [f"Set {i}" for i in range(1, 6)])
plt.xlabel("Hyperparameter Set")
plt.ylabel("R² Score")
plt.title("R² Comparison: CLEAN vs NOISY")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import os
save_dir = "saved_models/lstm"
os.makedirs(save_dir, exist_ok=True)

for res in results_lstm:
    data_mode = res["data_mode"]
    set_id = res["set"]
    model = res["model"]

    filename = f"lstm_{data_mode}_set{set_id}.pt"
    save_path = os.path.join(save_dir, filename)

    torch.save(model.state_dict(), save_path)

# %% [markdown]
# 2. GRU Autoencoder(Code from Checkpoint)

# %%
import torch
import torch.nn as nn

class GRU_Autoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers, dropout, output_seq_len):
        super(GRU_Autoencoder, self).__init__()
        self.output_seq_len = output_seq_len

        self.encoder = nn.GRU(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0
        )

        self.decoder = nn.GRU(
            input_size=hidden_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0
        )

        self.output_layer = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # Encoder
        _, hidden = self.encoder(x)

        # Decoder input: repeat last hidden state across output_seq_len steps
        decoder_input = hidden[-1].unsqueeze(1).repeat(1, self.output_seq_len, 1)

        # Decoder: use repeated hidden state and encoder output hidden state
        decoded_output, _ = self.decoder(decoder_input, hidden)

        # Project to output dim
        output = self.output_layer(decoded_output)
        return output

# %%
input_dim = X_train_clean.shape[2]
output_dim = y_train_clean.shape[2]
output_seq_len = y_train_clean.shape[1]
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameter sets: (hidden_dim, num_layers, dropout, learning_rate)
hyperparams_list = [
    (64, 1, 0.1, 0.001),
    (128, 1, 0.2, 0.001),
    (128, 2, 0.3, 0.0005),
    (256, 2, 0.3, 0.0003),
    (64, 3, 0.5, 0.0001),
]

results_gru = []

for data_mode in ['clean', 'noisy']:
    if data_mode == 'clean':
        train_loader, val_loader, test_loader = train_loader_clean, val_loader_clean, test_loader_clean
        y_test = y_test_clean
    else:
        train_loader, val_loader, test_loader = train_loader_noisy, val_loader_noisy, test_loader_noisy
        y_test = y_test_noisy

    for i, (hidden_dim, num_layers, dropout, lr) in enumerate(hyperparams_list, 1):
        print(f"Training [{data_mode.upper()}] GRU Set {i} — hidden={hidden_dim}, layers={num_layers}, dropout={dropout}, lr={lr}")

        model = GRU_Autoencoder(
            input_dim=input_dim,
            hidden_dim=hidden_dim,
            output_dim=output_dim,
            num_layers=num_layers,
            dropout=dropout,
            output_seq_len=output_seq_len
        ).to(device)

        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)

        # GRU_train (using lstm again)
        trained_model, train_losses, val_losses = train_lstm_model(
            model, train_loader, val_loader, epochs=20,
            criterion=criterion, optimizer=optimizer
        )

        # Test prediction
        model.eval()
        preds, targets = [], []
        with torch.no_grad():
            for x_batch, y_batch in test_loader:
                x_batch = x_batch.float().to(device)
                y_batch = y_batch.float().to(device)
                output = model(x_batch)
                preds.append(output.cpu().numpy())
                targets.append(y_batch.cpu().numpy())

        preds = np.concatenate(preds, axis=0).reshape(-1, output_dim)
        targets = np.concatenate(targets, axis=0).reshape(-1, output_dim)

        # Metrics
        mse = mean_squared_error(targets, preds)
        mae = mean_absolute_error(targets, preds)
        rmse = np.sqrt(mse)
        r2 = r2_score(targets, preds)

        # Save results
        results_gru.append({
            "data_mode": data_mode,
            "set": i,
            "hidden_dim": hidden_dim,
            "num_layers": num_layers,
            "dropout": dropout,
            "lr": lr,
            "train_losses": train_losses,
            "val_losses": val_losses,
            "test_mse": mse,
            "test_mae": mae,
            "test_rmse": rmse,
            "test_r2": r2,
            "model": trained_model
        })
# Out:
# Training [CLEAN] GRU Set 1 — hidden=64, layers=1, dropout=0.1, lr=0.001
# Epoch 1/20 | Train Loss: 0.0315 | Val Loss: 0.0535
# Epoch 2/20 | Train Loss: 0.0263 | Val Loss: 0.0499
# Epoch 3/20 | Train Loss: 0.0246 | Val Loss: 0.0474
# Epoch 4/20 | Train Loss: 0.0237 | Val Loss: 0.0455
# Epoch 5/20 | Train Loss: 0.0232 | Val Loss: 0.0442
# Epoch 6/20 | Train Loss: 0.0228 | Val Loss: 0.0430
# Epoch 7/20 | Train Loss: 0.0225 | Val Loss: 0.0416
# Epoch 8/20 | Train Loss: 0.0223 | Val Loss: 0.0399
# Epoch 9/20 | Train Loss: 0.0222 | Val Loss: 0.0383
# Epoch 10/20 | Train Loss: 0.0221 | Val Loss: 0.0366
# Epoch 11/20 | Train Loss: 0.0219 | Val Loss: 0.0350
# Epoch 12/20 | Train Loss: 0.0218 | Val Loss: 0.0336
# Epoch 13/20 | Train Loss: 0.0217 | Val Loss: 0.0325
# Epoch 14/20 | Train Loss: 0.0217 | Val Loss: 0.0316
# Epoch 15/20 | Train Loss: 0.0216 | Val Loss: 0.0310
# Epoch 16/20 | Train Loss: 0.0215 | Val Loss: 0.0306
# Epoch 17/20 | Train Loss: 0.0215 | Val Loss: 0.0303
# Epoch 18/20 | Train Loss: 0.0214 | Val Loss: 0.0302
# Epoch 19/20 | Train Loss: 0.0214 | Val Loss: 0.0298
# Epoch 20/20 | Train Loss: 0.0214 | Val Loss: 0.0305
# Training [CLEAN] GRU Set 2 — hidden=128, layers=1, dropout=0.2, lr=0.001
# Epoch 1/20 | Train Loss: 0.0295 | Val Loss: 0.0558
# Epoch 2/20 | Train Loss: 0.0247 | Val Loss: 0.0484
# Epoch 3/20 | Train Loss: 0.0234 | Val Loss: 0.0467
# Epoch 4/20 | Train Loss: 0.0227 | Val Loss: 0.0451
# Epoch 5/20 | Train Loss: 0.0223 | Val Loss: 0.0434
# Epoch 6/20 | Train Loss: 0.0221 | Val Loss: 0.0416
# Epoch 7/20 | Train Loss: 0.0219 | Val Loss: 0.0399
# Epoch 8/20 | Train Loss: 0.0217 | Val Loss: 0.0381
# Epoch 9/20 | Train Loss: 0.0215 | Val Loss: 0.0364
# Epoch 10/20 | Train Loss: 0.0214 | Val Loss: 0.0346
# Epoch 11/20 | Train Loss: 0.0213 | Val Loss: 0.0334
# Epoch 12/20 | Train Loss: 0.0212 | Val Loss: 0.0347
# Epoch 13/20 | Train Loss: 0.0211 | Val Loss: 0.0329
# Epoch 14/20 | Train Loss: 0.0210 | Val Loss: 0.0323
# Epoch 15/20 | Train Loss: 0.0210 | Val Loss: 0.0313
# Epoch 16/20 | Train Loss: 0.0209 | Val Loss: 0.0321
# Epoch 17/20 | Train Loss: 0.0209 | Val Loss: 0.0306
# Epoch 18/20 | Train Loss: 0.0208 | Val Loss: 0.0317
# Epoch 19/20 | Train Loss: 0.0208 | Val Loss: 0.0307
# Epoch 20/20 | Train Loss: 0.0207 | Val Loss: 0.0310
# Training [CLEAN] GRU Set 3 — hidden=128, layers=2, dropout=0.3, lr=0.0005
# Epoch 1/20 | Train Loss: 0.0320 | Val Loss: 0.0581
# Epoch 2/20 | Train Loss: 0.0265 | Val Loss: 0.0524
# Epoch 3/20 | Train Loss: 0.0247 | Val Loss: 0.0485
# Epoch 4/20 | Train Loss: 0.0238 | Val Loss: 0.0463
# Epoch 5/20 | Train Loss: 0.0231 | Val Loss: 0.0441
# Epoch 6/20 | Train Loss: 0.0227 | Val Loss: 0.0429
# Epoch 7/20 | Train Loss: 0.0224 | Val Loss: 0.0406
# Epoch 8/20 | Train Loss: 0.0221 | Val Loss: 0.0402
# Epoch 9/20 | Train Loss: 0.0220 | Val Loss: 0.0375
# Epoch 10/20 | Train Loss: 0.0218 | Val Loss: 0.0368
# Epoch 11/20 | Train Loss: 0.0217 | Val Loss: 0.0353
# Epoch 12/20 | Train Loss: 0.0216 | Val Loss: 0.0341
# Epoch 13/20 | Train Loss: 0.0215 | Val Loss: 0.0333
# Epoch 14/20 | Train Loss: 0.0213 | Val Loss: 0.0331
# Epoch 15/20 | Train Loss: 0.0213 | Val Loss: 0.0311
# Epoch 16/20 | Train Loss: 0.0212 | Val Loss: 0.0310
# Epoch 17/20 | Train Loss: 0.0211 | Val Loss: 0.0310
# Epoch 18/20 | Train Loss: 0.0210 | Val Loss: 0.0307
# Epoch 19/20 | Train Loss: 0.0210 | Val Loss: 0.0299
# Epoch 20/20 | Train Loss: 0.0209 | Val Loss: 0.0296
# Training [CLEAN] GRU Set 4 — hidden=256, layers=2, dropout=0.3, lr=0.0003
# Epoch 1/20 | Train Loss: 0.0316 | Val Loss: 0.0573
# Epoch 2/20 | Train Loss: 0.0263 | Val Loss: 0.0506
# Epoch 3/20 | Train Loss: 0.0245 | Val Loss: 0.0481
# Epoch 4/20 | Train Loss: 0.0234 | Val Loss: 0.0463
# Epoch 5/20 | Train Loss: 0.0227 | Val Loss: 0.0437
# Epoch 6/20 | Train Loss: 0.0223 | Val Loss: 0.0419
# Epoch 7/20 | Train Loss: 0.0220 | Val Loss: 0.0406
# Epoch 8/20 | Train Loss: 0.0218 | Val Loss: 0.0392
# Epoch 9/20 | Train Loss: 0.0216 | Val Loss: 0.0375
# Epoch 10/20 | Train Loss: 0.0215 | Val Loss: 0.0357
# Epoch 11/20 | Train Loss: 0.0213 | Val Loss: 0.0359
# Epoch 12/20 | Train Loss: 0.0212 | Val Loss: 0.0344
# Epoch 13/20 | Train Loss: 0.0211 | Val Loss: 0.0309
# Epoch 14/20 | Train Loss: 0.0211 | Val Loss: 0.0341
# Epoch 15/20 | Train Loss: 0.0210 | Val Loss: 0.0323
# Epoch 16/20 | Train Loss: 0.0208 | Val Loss: 0.0317
# Epoch 17/20 | Train Loss: 0.0208 | Val Loss: 0.0307
# Epoch 18/20 | Train Loss: 0.0206 | Val Loss: 0.0299
# Epoch 19/20 | Train Loss: 0.0206 | Val Loss: 0.0298
# Epoch 20/20 | Train Loss: 0.0205 | Val Loss: 0.0301
# Training [CLEAN] GRU Set 5 — hidden=64, layers=3, dropout=0.5, lr=0.0001
# Epoch 1/20 | Train Loss: 0.0479 | Val Loss: 0.0628
# Epoch 2/20 | Train Loss: 0.0358 | Val Loss: 0.0557
# Epoch 3/20 | Train Loss: 0.0326 | Val Loss: 0.0531
# Epoch 4/20 | Train Loss: 0.0311 | Val Loss: 0.0512
# Epoch 5/20 | Train Loss: 0.0302 | Val Loss: 0.0503
# Epoch 6/20 | Train Loss: 0.0294 | Val Loss: 0.0503
# Epoch 7/20 | Train Loss: 0.0289 | Val Loss: 0.0494
# Epoch 8/20 | Train Loss: 0.0285 | Val Loss: 0.0480
# Epoch 9/20 | Train Loss: 0.0282 | Val Loss: 0.0467
# Epoch 10/20 | Train Loss: 0.0279 | Val Loss: 0.0455
# Epoch 11/20 | Train Loss: 0.0276 | Val Loss: 0.0440
# Epoch 12/20 | Train Loss: 0.0274 | Val Loss: 0.0429
# Epoch 13/20 | Train Loss: 0.0272 | Val Loss: 0.0422
# Epoch 14/20 | Train Loss: 0.0270 | Val Loss: 0.0415
# Epoch 15/20 | Train Loss: 0.0268 | Val Loss: 0.0408
# Epoch 16/20 | Train Loss: 0.0266 | Val Loss: 0.0400
# Epoch 17/20 | Train Loss: 0.0264 | Val Loss: 0.0393
# Epoch 18/20 | Train Loss: 0.0262 | Val Loss: 0.0388
# Epoch 19/20 | Train Loss: 0.0261 | Val Loss: 0.0382
# Epoch 20/20 | Train Loss: 0.0259 | Val Loss: 0.0378
# Training [NOISY] GRU Set 1 — hidden=64, layers=1, dropout=0.1, lr=0.001
# Epoch 1/20 | Train Loss: 0.0249 | Val Loss: 0.0421
# Epoch 2/20 | Train Loss: 0.0213 | Val Loss: 0.0396
# Epoch 3/20 | Train Loss: 0.0205 | Val Loss: 0.0384
# Epoch 4/20 | Train Loss: 0.0202 | Val Loss: 0.0382
# Epoch 5/20 | Train Loss: 0.0200 | Val Loss: 0.0378
# Epoch 6/20 | Train Loss: 0.0198 | Val Loss: 0.0377
# Epoch 7/20 | Train Loss: 0.0197 | Val Loss: 0.0368
# Epoch 8/20 | Train Loss: 0.0196 | Val Loss: 0.0362
# Epoch 9/20 | Train Loss: 0.0195 | Val Loss: 0.0353
# Epoch 10/20 | Train Loss: 0.0194 | Val Loss: 0.0333
# Epoch 11/20 | Train Loss: 0.0193 | Val Loss: 0.0316
# Epoch 12/20 | Train Loss: 0.0192 | Val Loss: 0.0304
# Epoch 13/20 | Train Loss: 0.0191 | Val Loss: 0.0288
# Epoch 14/20 | Train Loss: 0.0191 | Val Loss: 0.0276
# Epoch 15/20 | Train Loss: 0.0190 | Val Loss: 0.0264
# Epoch 16/20 | Train Loss: 0.0190 | Val Loss: 0.0257
# Epoch 17/20 | Train Loss: 0.0189 | Val Loss: 0.0251
# Epoch 18/20 | Train Loss: 0.0189 | Val Loss: 0.0245
# Epoch 19/20 | Train Loss: 0.0189 | Val Loss: 0.0239
# Epoch 20/20 | Train Loss: 0.0188 | Val Loss: 0.0235
# Training [NOISY] GRU Set 2 — hidden=128, layers=1, dropout=0.2, lr=0.001
# Epoch 1/20 | Train Loss: 0.0237 | Val Loss: 0.0402
# Epoch 2/20 | Train Loss: 0.0206 | Val Loss: 0.0375
# Epoch 3/20 | Train Loss: 0.0200 | Val Loss: 0.0360
# Epoch 4/20 | Train Loss: 0.0197 | Val Loss: 0.0357
# Epoch 5/20 | Train Loss: 0.0195 | Val Loss: 0.0352
# Epoch 6/20 | Train Loss: 0.0194 | Val Loss: 0.0345
# Epoch 7/20 | Train Loss: 0.0193 | Val Loss: 0.0337
# Epoch 8/20 | Train Loss: 0.0192 | Val Loss: 0.0327
# Epoch 9/20 | Train Loss: 0.0191 | Val Loss: 0.0318
# Epoch 10/20 | Train Loss: 0.0190 | Val Loss: 0.0312
# Epoch 11/20 | Train Loss: 0.0190 | Val Loss: 0.0302
# Epoch 12/20 | Train Loss: 0.0189 | Val Loss: 0.0284
# Epoch 13/20 | Train Loss: 0.0189 | Val Loss: 0.0269
# Epoch 14/20 | Train Loss: 0.0188 | Val Loss: 0.0259
# Epoch 15/20 | Train Loss: 0.0187 | Val Loss: 0.0254
# Epoch 16/20 | Train Loss: 0.0187 | Val Loss: 0.0253
# Epoch 17/20 | Train Loss: 0.0187 | Val Loss: 0.0249
# Epoch 18/20 | Train Loss: 0.0187 | Val Loss: 0.0258
# Epoch 19/20 | Train Loss: 0.0186 | Val Loss: 0.0258
# Epoch 20/20 | Train Loss: 0.0186 | Val Loss: 0.0250
# Training [NOISY] GRU Set 3 — hidden=128, layers=2, dropout=0.3, lr=0.0005
# Epoch 1/20 | Train Loss: 0.0258 | Val Loss: 0.0443
# Epoch 2/20 | Train Loss: 0.0213 | Val Loss: 0.0411
# Epoch 3/20 | Train Loss: 0.0206 | Val Loss: 0.0395
# Epoch 4/20 | Train Loss: 0.0201 | Val Loss: 0.0383
# Epoch 5/20 | Train Loss: 0.0199 | Val Loss: 0.0377
# Epoch 6/20 | Train Loss: 0.0197 | Val Loss: 0.0367
# Epoch 7/20 | Train Loss: 0.0195 | Val Loss: 0.0358
# Epoch 8/20 | Train Loss: 0.0194 | Val Loss: 0.0348
# Epoch 9/20 | Train Loss: 0.0193 | Val Loss: 0.0338
# Epoch 10/20 | Train Loss: 0.0192 | Val Loss: 0.0327
# Epoch 11/20 | Train Loss: 0.0191 | Val Loss: 0.0312
# Epoch 12/20 | Train Loss: 0.0191 | Val Loss: 0.0300
# Epoch 13/20 | Train Loss: 0.0190 | Val Loss: 0.0284
# Epoch 14/20 | Train Loss: 0.0189 | Val Loss: 0.0275
# Epoch 15/20 | Train Loss: 0.0189 | Val Loss: 0.0263
# Epoch 16/20 | Train Loss: 0.0188 | Val Loss: 0.0257
# Epoch 17/20 | Train Loss: 0.0188 | Val Loss: 0.0259
# Epoch 18/20 | Train Loss: 0.0188 | Val Loss: 0.0253
# Epoch 19/20 | Train Loss: 0.0187 | Val Loss: 0.0236
# Epoch 20/20 | Train Loss: 0.0187 | Val Loss: 0.0240
# Training [NOISY] GRU Set 4 — hidden=256, layers=2, dropout=0.3, lr=0.0003
# Epoch 1/20 | Train Loss: 0.0255 | Val Loss: 0.0438
# Epoch 2/20 | Train Loss: 0.0213 | Val Loss: 0.0407
# Epoch 3/20 | Train Loss: 0.0205 | Val Loss: 0.0389
# Epoch 4/20 | Train Loss: 0.0201 | Val Loss: 0.0377
# Epoch 5/20 | Train Loss: 0.0198 | Val Loss: 0.0371
# Epoch 6/20 | Train Loss: 0.0196 | Val Loss: 0.0367
# Epoch 7/20 | Train Loss: 0.0195 | Val Loss: 0.0354
# Epoch 8/20 | Train Loss: 0.0193 | Val Loss: 0.0342
# Epoch 9/20 | Train Loss: 0.0192 | Val Loss: 0.0332
# Epoch 10/20 | Train Loss: 0.0191 | Val Loss: 0.0312
# Epoch 11/20 | Train Loss: 0.0191 | Val Loss: 0.0301
# Epoch 12/20 | Train Loss: 0.0190 | Val Loss: 0.0285
# Epoch 13/20 | Train Loss: 0.0189 | Val Loss: 0.0270
# Epoch 14/20 | Train Loss: 0.0189 | Val Loss: 0.0275
# Epoch 15/20 | Train Loss: 0.0188 | Val Loss: 0.0253
# Epoch 16/20 | Train Loss: 0.0188 | Val Loss: 0.0242
# Epoch 17/20 | Train Loss: 0.0187 | Val Loss: 0.0252
# Epoch 18/20 | Train Loss: 0.0187 | Val Loss: 0.0249
# Epoch 19/20 | Train Loss: 0.0186 | Val Loss: 0.0253
# Epoch 20/20 | Train Loss: 0.0186 | Val Loss: 0.0248
# Training [NOISY] GRU Set 5 — hidden=64, layers=3, dropout=0.5, lr=0.0001
# Epoch 1/20 | Train Loss: 0.0408 | Val Loss: 0.0530
# Epoch 2/20 | Train Loss: 0.0275 | Val Loss: 0.0461
# Epoch 3/20 | Train Loss: 0.0250 | Val Loss: 0.0425
# Epoch 4/20 | Train Loss: 0.0238 | Val Loss: 0.0408
# Epoch 5/20 | Train Loss: 0.0232 | Val Loss: 0.0396
# Epoch 6/20 | Train Loss: 0.0227 | Val Loss: 0.0386
# Epoch 7/20 | Train Loss: 0.0223 | Val Loss: 0.0378
# Epoch 8/20 | Train Loss: 0.0221 | Val Loss: 0.0372
# Epoch 9/20 | Train Loss: 0.0219 | Val Loss: 0.0366
# Epoch 10/20 | Train Loss: 0.0217 | Val Loss: 0.0358
# Epoch 11/20 | Train Loss: 0.0215 | Val Loss: 0.0351
# Epoch 12/20 | Train Loss: 0.0213 | Val Loss: 0.0342
# Epoch 13/20 | Train Loss: 0.0212 | Val Loss: 0.0335
# Epoch 14/20 | Train Loss: 0.0211 | Val Loss: 0.0327
# Epoch 15/20 | Train Loss: 0.0210 | Val Loss: 0.0320
# Epoch 16/20 | Train Loss: 0.0208 | Val Loss: 0.0313
# Epoch 17/20 | Train Loss: 0.0207 | Val Loss: 0.0308
# Epoch 18/20 | Train Loss: 0.0207 | Val Loss: 0.0302
# Epoch 19/20 | Train Loss: 0.0206 | Val Loss: 0.0297
# Epoch 20/20 | Train Loss: 0.0205 | Val Loss: 0.0294

# %%
from tabulate import tabulate

# Collect evaluation summary
summary = []
for res in results_gru:
    row = [
        res["data_mode"].upper(),
        res["set"],
        res["hidden_dim"],
        res["num_layers"],
        res["dropout"],
        res["lr"],
        round(res["train_losses"][-1], 6),
        round(res["val_losses"][-1], 6),
        round(res["test_mse"], 6),
        round(res["test_mae"], 6),
        round(res["test_rmse"], 6),
        round(res["test_r2"], 6),
    ]
    summary.append(row)

# Table headers
headers = [
    "Data", "Set", "Hidden", "Layers", "Dropout", "LR",
    "Final Train Loss", "Final Val Loss",
    "Test MSE", "Test MAE", "Test RMSE", "Test R²"
]

# Print neatly
print(tabulate(summary, headers=headers, tablefmt="grid"))
# Out:
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | Data   |   Set |   Hidden |   Layers |   Dropout |     LR |   Final Train Loss |   Final Val Loss |   Test MSE |   Test MAE |   Test RMSE |   Test R² |
# +========+=======+==========+==========+===========+========+====================+==================+============+============+=============+===========+
# | CLEAN  |     1 |       64 |        1 |       0.1 | 0.001  |           0.02136  |         0.030481 |   0.027416 |   0.10977  |    0.165579 |  0.610336 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | CLEAN  |     2 |      128 |        1 |       0.2 | 0.001  |           0.020719 |         0.030968 |   0.028301 |   0.110517 |    0.168229 |  0.599201 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | CLEAN  |     3 |      128 |        2 |       0.3 | 0.0005 |           0.02091  |         0.029602 |   0.026579 |   0.106866 |    0.163029 |  0.621158 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | CLEAN  |     4 |      256 |        2 |       0.3 | 0.0003 |           0.02047  |         0.030079 |   0.027564 |   0.107078 |    0.166025 |  0.611904 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | CLEAN  |     5 |       64 |        3 |       0.5 | 0.0001 |           0.025911 |         0.037798 |   0.03542  |   0.129726 |    0.188202 |  0.507397 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     1 |       64 |        1 |       0.1 | 0.001  |           0.018817 |         0.023477 |   0.021239 |   0.10767  |    0.145736 |  0.221615 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     2 |      128 |        1 |       0.2 | 0.001  |           0.01858  |         0.024989 |   0.023285 |   0.110663 |    0.152596 |  0.198287 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     3 |      128 |        2 |       0.3 | 0.0005 |           0.018669 |         0.023962 |   0.021837 |   0.108333 |    0.147773 |  0.213316 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     4 |      256 |        2 |       0.3 | 0.0003 |           0.01862  |         0.024769 |   0.022465 |   0.109484 |    0.149884 |  0.207829 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+
# | NOISY  |     5 |       64 |        3 |       0.5 | 0.0001 |           0.020513 |         0.029382 |   0.027764 |   0.118269 |    0.166626 |  0.142908 |
# +--------+-------+----------+----------+-----------+--------+--------------------+------------------+------------+------------+-------------+-----------+

# %%
df = pd.DataFrame(results_gru)

df["Label"] = df["data_mode"].str.upper() + "_Set" + df["set"].astype(str)

# 1. Final Train & Val Loss
plt.figure(figsize=(12, 5))
x = np.arange(len(df))
bar_width = 0.35
plt.bar(x - bar_width/2, [l[-1] for l in df["train_losses"]], width=bar_width, label='Train Loss')
plt.bar(x + bar_width/2, [l[-1] for l in df["val_losses"]], width=bar_width, label='Val Loss')
plt.xticks(x, df["Label"], rotation=45)
plt.ylabel("Loss")
plt.title("GRU: Final Train vs Validation Loss")
plt.legend()
plt.tight_layout()
plt.show()

# 2. Test MSE, MAE, RMSE
plt.figure(figsize=(12, 5))
bar_width = 0.25
plt.bar(x - bar_width, df["test_mse"], width=bar_width, label="MSE")
plt.bar(x, df["test_mae"], width=bar_width, label="MAE")
plt.bar(x + bar_width, df["test_rmse"], width=bar_width, label="RMSE")
plt.xticks(x, df["Label"], rotation=45)
plt.ylabel("Error")
plt.title("GRU: Test Error Metrics (MSE, MAE, RMSE)")
plt.legend()
plt.tight_layout()
plt.show()

# 3. R² Scores
plt.figure(figsize=(12, 5))
plt.bar(df["Label"], df["test_r2"])
plt.xticks(rotation=45)
plt.ylabel("R² Score")
plt.title("GRU: Test R² Scores by Model")
plt.tight_layout()
plt.show()

# 4. R²: Clean vs Noisy
plt.figure(figsize=(10, 5))
for mode in ["CLEAN", "NOISY"]:
    r2_vals = df[df["data_mode"] == mode.lower()]["test_r2"]
    plt.plot(range(1, 6), r2_vals, marker='o', label=mode)
plt.xticks(range(1, 6), [f"Set {i}" for i in range(1, 6)])
plt.xlabel("Hyperparameter Set")
plt.ylabel("R² Score")
plt.title("GRU: R² Comparison - CLEAN vs NOISY")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
save_dir = "saved_models/gru"
os.makedirs(save_dir, exist_ok=True)

for res in results_gru:
    data_mode = res["data_mode"]
    set_id = res["set"]
    model = res["model"]

    filename = f"gru_{data_mode}_set{set_id}.pt"
    save_path = os.path.join(save_dir, filename)

    torch.save(model.state_dict(), save_path)

# %%
# !zip -r saved_models.zip /content/saved_models
from google.colab import files
files.download('saved_models.zip')
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/gru/ (stored 0%)
#   adding: content/saved_models/gru/gru_noisy_set2.pt (deflated 7%)
#   adding: content/saved_models/gru/gru_noisy_set4.pt (deflated 7%)
#   adding: content/saved_models/gru/gru_clean_set3.pt (deflated 7%)
#   adding: content/saved_models/gru/gru_clean_set5.pt (deflated 8%)
#   adding: content/saved_models/gru/gru_clean_set2.pt (deflated 7%)
#   adding: content/saved_models/gru/gru_noisy_set5.pt (deflated 8%)
#   adding: content/saved_models/gru/gru_clean_set4.pt (deflated 7%)
#   adding: content/saved_models/gru/gru_noisy_set3.pt (deflated 7%)
#   adding: content/saved_models/gru/gru_clean_set1.pt (deflated 8%)
#   adding: content/saved_models/gru/gru_noisy_set1.pt (deflated 8%)
#   adding: content/saved_models/lstm/ (stored 0%)
#   adding: content/saved_models/lstm/lstm_clean_set2.pt (deflated 7%)
#   adding: content/saved_models/lstm/lstm_noisy_set3.pt (deflated 7%)
#   adding: content/saved_models/lstm/lstm_clean_set4.pt (deflated 7%)
#   adding: content/saved_models/lstm/lstm_noisy_set5.pt (deflated 8%)
#   adding: content/saved_models/lstm/lstm_clean_set3.pt (deflated 7%)
#   adding: content/saved_models/lstm/lstm_noisy_set4.pt (deflated 7%)
#   adding: content/saved_models/lstm/lstm_clean_set5.pt (deflated 8%)
#   adding: content/saved_models/lstm/lstm_clean_set1.pt (deflated 8%)
#   adding: content/saved_models/lstm/lstm_noisy_set1.pt (deflated 8%)
#   adding: content/saved_models/lstm/lstm_noisy_set2.pt (deflated 7%)

# %%
results_lstm = [
    {
        "data_mode": "clean",
        "set": 2,
        "hidden_dim": 128,
        "num_layers": 1,
        "dropout": 0.2,
        "lr": 0.001,
        "train_losses": [0.020756],
        "val_losses": [0.031948],
        "test_mse": 0.029914,
        "test_mae": 0.111882,
        "test_rmse": 0.172955,
        "test_r2": 0.579171,
        "model": None,
    },
    {
        "data_mode": "noisy",
        "set": 2,
        "hidden_dim": 128,
        "num_layers": 1,
        "dropout": 0.2,
        "lr": 0.001,
        "train_losses": [0.018703],
        "val_losses": [0.024432],
        "test_mse": 0.022538,
        "test_mae": 0.109349,
        "test_rmse": 0.150127,
        "test_r2": 0.208305,
        "model": None,
    }
]

results_gru = [
    {
        "data_mode": "clean",
        "set": 3,
        "hidden_dim": 128,
        "num_layers": 2,
        "dropout": 0.3,
        "lr": 0.0005,
        "train_losses": [0.02091],
        "val_losses": [0.029602],
        "test_mse": 0.026579,
        "test_mae": 0.106866,
        "test_rmse": 0.163029,
        "test_r2": 0.621158,
        "model": None,
    },
    {
        "data_mode": "noisy",
        "set": 1,
        "hidden_dim": 64,
        "num_layers": 1,
        "dropout": 0.1,
        "lr": 0.001,
        "train_losses": [0.018817],
        "val_losses": [0.023477],
        "test_mse": 0.021239,
        "test_mae": 0.10767,
        "test_rmse": 0.145736,
        "test_r2": 0.221615,
        "model": None,
    }
]

def build_summary(results, model_name):
    summary = []
    for res in results:
        row = [
            res["data_mode"].upper(),
            res["set"],
            res["hidden_dim"],
            res["num_layers"],
            res["dropout"],
            res["lr"],
            round(res["train_losses"][-1], 6),
            round(res["val_losses"][-1], 6),
            round(res["test_mse"], 6),
            round(res["test_mae"], 6),
            round(res["test_rmse"], 6),
            round(res["test_r2"], 6),
            model_name
        ]
        summary.append(row)
    return summary

headers = [
    "Data", "Set", "Hidden", "Layers", "Dropout", "LR",
    "Final Train Loss", "Final Val Loss",
    "Test MSE", "Test MAE", "Test RMSE", "Test R²", "Model"
]


lstm_summary = build_summary(results_lstm, "LSTM")
gru_summary = build_summary(results_gru, "GRU")


all_summary = lstm_summary + gru_summary
summary_df = pd.DataFrame(all_summary, columns=headers)


best_df = (
    summary_df.sort_values(by=["Model", "Data", "Test MSE", "Test R²"], ascending=[True, True, True, False])
    .groupby(["Model", "Data"])
    .first()
    .reset_index()
)

print (best_df)
# Out:
#   Model   Data  Set  Hidden  Layers  Dropout      LR  Final Train Loss  \
# 0   GRU  CLEAN    3     128       2      0.3  0.0005          0.020910
# 1   GRU  NOISY    1      64       1      0.1  0.0010          0.018817
# 2  LSTM  CLEAN    2     128       1      0.2  0.0010          0.020756
# 3  LSTM  NOISY    2     128       1      0.2  0.0010          0.018703
#
#    Final Val Loss  Test MSE  Test MAE  Test RMSE   Test R²
# 0        0.029602  0.026579  0.106866   0.163029  0.621158
# 1        0.023477  0.021239  0.107670   0.145736  0.221615
# 2        0.031948  0.029914  0.111882   0.172955  0.579171
# 3        0.024432  0.022538  0.109349   0.150127  0.208305

# %%
def generate_model_name(row):
    return f"{row['Model']}_{row['Data']}_Set{row['Set']}_H{row['Hidden']}_L{row['Layers']}_D{row['Dropout']}_LR{row['LR']}"

best_df["Model_Name"] = best_df.apply(generate_model_name, axis=1)

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 6))

x_labels = best_df["Model_Name"].tolist()
x = range(len(x_labels))

axs[0].bar(x, best_df["Test R²"], color="lightgreen")
axs[0].set_title("Test R²")
axs[0].set_ylabel("R² Score")
axs[0].set_xticks(x)
axs[0].set_xticklabels(x_labels, rotation=45, ha="right")
axs[0].grid(axis="y", linestyle="--", alpha=0.5)

axs[1].bar(x, best_df["Test MAE"], color="salmon")
axs[1].set_title("Test MAE")
axs[1].set_ylabel("MAE")
axs[1].set_xticks(x)
axs[1].set_xticklabels(x_labels, rotation=45, ha="right")
axs[1].grid(axis="y", linestyle="--", alpha=0.5)

axs[2].bar(x, best_df["Test RMSE"], color="cornflowerblue")
axs[2].set_title("Test RMSE")
axs[2].set_ylabel("RMSE")
axs[2].set_xticks(x)
axs[2].set_xticklabels(x_labels, rotation=45, ha="right")
axs[2].grid(axis="y", linestyle="--", alpha=0.5)

plt.suptitle("Evaluation Metrics for Best GRU & LSTM Models (with Set & Parameters)")
plt.tight_layout()
plt.show()

# %%
def normalize(series):
    return (series - series.min()) / (series.max() - series.min())

normalized_df = best_df.copy()
normalized_df["Norm R²"] = normalize(best_df["Test R²"])
normalized_df["Norm MAE"] = 1 - normalize(best_df["Test MAE"])  
normalized_df["Norm RMSE"] = 1 - normalize(best_df["Test RMSE"])  

labels = ["R²", "MAE", "RMSE"]
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]

# Plot
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

for _, row in normalized_df.iterrows():
    values = [row["Norm R²"], row["Norm MAE"], row["Norm RMSE"]]
    values += values[:1]
    ax.plot(angles, values, label=row["Model_Name"], linewidth=2)
    ax.fill(angles, values, alpha=0.25)

ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), labels)
ax.set_ylim(0, 1)
ax.set_title("Radar Plot of Normalized Metrics (with Model Names)", pad=20)
ax.legend(loc="upper right", bbox_to_anchor=(1.3, 1.1))
plt.tight_layout()
plt.show()
